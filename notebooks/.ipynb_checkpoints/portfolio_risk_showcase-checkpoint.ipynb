# %% [markdown]
# # Multi-Asset Portfolio Risk Analytics
#
# This notebook demonstrates a concise, reproducible market- and portfolio-risk workflow. It uses synthetic data so the analysis can be run and reviewed without a market-data subscription.

# %% [markdown]
# ## 1. Setup
#
# The notebook imports reusable modules from `src/portfolio_risk`; the analysis code stays short because the risk logic is independently testable.

# %%
import os
import sys

PROJECT_ROOT = '/Users/rowanwalker/rowan-env-312/portfolio-risk-engine'
os.environ['MPLCONFIGDIR'] = PROJECT_ROOT + '/.matplotlib'
# Jupyter can keep an inaccessible working directory in sys.path. Remove it before importing packages.
sys.path = [path for path in sys.path if path not in ('', '.')]
sys.path.insert(0, PROJECT_ROOT + '/src')

import matplotlib.pyplot as plt
import pandas as pd
import seaborn as sns

from portfolio_risk.config import ASSET_CLASSES, CONFIDENCE_LEVEL, RISK_LIMITS, WEIGHTS
from portfolio_risk.factor_risk import default_factor_exposures, portfolio_factor_exposure
from portfolio_risk.market_data import generate_market_data
from portfolio_risk.portfolio import asset_class_exposure, portfolio_returns
from portfolio_risk.risk_metrics import component_var, rolling_risk_metrics
from portfolio_risk.risk_monitor import latest_alerts, risk_summary
from portfolio_risk.stress_testing import default_scenarios, run_stress_tests

sns.set_theme(style='whitegrid', context='notebook')
pd.options.display.float_format = '{:,.2%}'.format

# %% [markdown]
# ## 2. Portfolio and market data

# %%
returns = generate_market_data()
portfolio_pnl = portfolio_returns(returns, WEIGHTS)

display(pd.DataFrame({'weight': WEIGHTS, 'asset_class': ASSET_CLASSES}))
display(asset_class_exposure(WEIGHTS, ASSET_CLASSES).to_frame())
# Out:
#                          weight asset_class
# US_Equity                28.00%      Equity
# Europe_Equity            17.00%      Equity
# US_10Y_Rates             20.00%       Rates
# Investment_Grade_Credit  15.00%      Credit
# EURUSD                    8.00%          FX
# Gold                     12.00%   Commodity
#            weight
# Equity     45.00%
# Rates      20.00%
# Credit     15.00%
# Commodity  12.00%
# FX          8.00%

# %% [markdown]
# ## 3. Risk monitoring
#
# Historical VaR and Expected Shortfall are reported alongside pre-defined risk appetite limits.

# %%
summary = risk_summary(portfolio_pnl, RISK_LIMITS)
display(summary.style.applymap(lambda value: 'background-color: #ffd6d6' if value == 'BREACH' else '', subset=['status']))

rolling = rolling_risk_metrics(portfolio_pnl, confidence=CONFIDENCE_LEVEL)
display(latest_alerts(rolling, RISK_LIMITS))
# Out:
# /var/folders/jj/r0dn4_597_9fm9w3q_85t9140000gn/T/ipykernel_5944/3291019972.py:2: FutureWarning: Styler.applymap has been deprecated. Use Styler.map instead.
#   display(summary.style.applymap(lambda value: 'background-color: #ffd6d6' if value == 'BREACH' else '', subset=['status']))
# <style type="text/css">
# </style>
# <table id="T_53346">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_53346_level0_col0" class="col_heading level0 col0" >value</th>
#       <th id="T_53346_level0_col1" class="col_heading level0 col1" >limit</th>
#       <th id="T_53346_level0_col2" class="col_heading level0 col2" >utilisation</th>
#       <th id="T_53346_level0_col3" class="col_heading level0 col3" >status</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_53346_level0_row0" class="row_heading level0 row0" >1-day historical VaR (95%)</th>
#       <td id="T_53346_row0_col0" class="data row0 col0" >0.009300</td>
# ...

# %%
fig, axes = plt.subplots(2, 1, figsize=(12, 8), sharex=True)
(1 + portfolio_pnl).cumprod().plot(ax=axes[0], color='#003E6B', lw=2, title='Portfolio cumulative return')
axes[0].set_ylabel('Growth of £1')
rolling[['annualised_volatility', 'var_95', 'es_95']].plot(ax=axes[1], lw=1.5, title='Rolling 63-day risk metrics')
axes[1].axhline(RISK_LIMITS['annualised_volatility'], color='tab:red', ls='--', label='Volatility limit')
axes[1].set_ylabel('Risk measure')
axes[1].legend(ncol=2)
plt.tight_layout()

# %% [markdown]
# ## 4. Diversification and factor risk
#
# Component VaR highlights which positions drive total risk. Factor exposures provide a complementary, explainable view of market sensitivities.

# %%
components = component_var(returns, WEIGHTS).sort_values()
factors = default_factor_exposures(list(returns.columns))
factor_exposure = portfolio_factor_exposure(WEIGHTS, factors).sort_values()

fig, axes = plt.subplots(1, 2, figsize=(14, 5))
components.plot.barh(ax=axes[0], color='#337ab7', title='Component parametric VaR by position')
axes[0].set_xlabel('One-day VaR contribution')
factor_exposure.plot.barh(ax=axes[1], color='#5cb85c', title='Portfolio factor exposures')
axes[1].set_xlabel('Exposure')
plt.tight_layout()

plt.figure(figsize=(8, 5))
sns.heatmap(returns.corr(), cmap='vlag', center=0, annot=True, fmt='.2f')
plt.title('Asset-return correlation matrix')
plt.tight_layout()

# %% [markdown]
# ## 5. Stress testing and risk-committee takeaways

# %%
stress_results = run_stress_tests(WEIGHTS, default_scenarios())
display(stress_results.style.format('{:.2%}').background_gradient(cmap='RdYlGn', subset=['Total']))

stress_results['Total'].sort_values().plot.barh(figsize=(9, 4), color='#d9534f', title='Hypothetical stress-test portfolio P&L')
plt.xlabel('Portfolio return')
plt.tight_layout()

worst_scenario = stress_results['Total'].idxmin()
largest_risk_driver = components.idxmax()
print(f'Risk committee summary: {worst_scenario} is the largest hypothetical loss; {largest_risk_driver} is the largest component-VaR contributor.')
# Out:
# <style type="text/css">
# #T_364cb_row0_col6 {
#   background-color: #a50026;
#   color: #f1f1f1;
# }
# #T_364cb_row1_col6 {
#   background-color: #fdb768;
#   color: #000000;
# }
# #T_364cb_row2_col6 {
#   background-color: #fdb96a;
#   color: #000000;
# }
# #T_364cb_row3_col6 {
#   background-color: #006837;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_364cb">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_364cb_level0_col0" class="col_heading level0 col0" >US_Equity</th>
#       <th id="T_364cb_level0_col1" class="col_heading level0 col1" >Europe_Equity</th>
#       <th id="T_364cb_level0_col2" class="col_heading level0 col2" >US_10Y_Rates</th>
#       <th id="T_364cb_level0_col3" class="col_heading level0 col3" >Investment_Grade_Credit</th>
#       <th id="T_364cb_level0_col4" class="col_heading level0 col4" >EURUSD</th>
#       <th id="T_364cb_level0_col5" class="col_heading level0 col5" >Gold</th>
# ...
